# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import glob
import scipy.stats as st
import datetime as dt
from datetime import datetime
import matplotlib.dates as mdates

# Study data files
pm25_data_path = "../Resources/aqi.csv"
ozone_data_path = "../Resources/ozone.csv"
covid_path = "../Resources/mn-c19.csv"
#Traffic_Data = "data/MNDOT.csv"

# Read the PM2.5 data and the Ozone Data
pm25_data = pd.read_csv(pm25_data_path)
ozone_data = pd.read_csv(ozone_data_path)

#Combine all AQI files
Combined_AQI_csv=pd.merge(pm25_data,ozone_data,on="Date",how="left")
#Export to CSV
Combined_AQI_csv.to_csv( "../Resources/Combined_AQI_csv.csv", index=False)
Combined_AQI_csv.head()

# add covid data
combine_path = "../Resources/Combined_AQI_csv.csv"
combine_data = pd.read_csv(combine_path)
covid_data = pd.read_csv(covid_path)
combined_aqi_covid = pd.merge(combine_data, covid_data,on="Date",how="left")

#export to csv
combined_aqi_covid.to_csv("../Resources/combined_aqi_covid.csv", index=False)
Combined_AQI_csv.head()
# Out:
#        Date Source_x  Site ID_x  POC_x  Daily Mean PM2.5 Concentration  \
# 0  1/1/2015      AQS  270530962      3                             7.7
# 1  1/2/2015      AQS  270530962      3                             7.5
# 2  1/3/2015      AQS  270530962      3                            14.1
# 3  1/4/2015      AQS  270530962      3                             9.4
# 4  1/5/2015      AQS  270530962      3                            10.5
#
#     UNITS_x  DAILY_AQI_VALUE_x          Site Name_x  DAILY_OBS_COUNT_x  \
# 0  ug/m3 LC                 32  Near Road I-35/I-94                  1
# 1  ug/m3 LC                 31  Near Road I-35/I-94                  1
# 2  ug/m3 LC                 55  Near Road I-35/I-94                  1
# 3  ug/m3 LC                 39  Near Road I-35/I-94                  1
# 4  ug/m3 LC                 44  Near Road I-35/I-94                  1
#
#    PERCENT_COMPLETE_x  ...  AQS_PARAMETER_CODE_y AQS_PARAMETER_DESC_y  \
# ...

# %%
#Create plot tracking AQI change over time
PM25 = Combined_AQI_csv["Daily Mean PM2.5 Concentration"]
dates = Combined_AQI_csv['Date']

plt.figure(figsize=(15,3))

ax = plt.gca()
dates = [datetime.strptime(d, "%m/%d/%Y") for d in dates]
ax.set_xlim([dates[0], dates[-1]])
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mdates.MonthLocator(bymonth=(3,6,9), bymonthday=-1))
ax.xaxis.set_minor_formatter(mdates.DateFormatter('%b'))

plt.plot(dates,PM25,color="g")
plt.title("PM2.5 Concentration Over Time")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.ylabel("PM2.5 Concentration (ug/m3 LC)")

#PM2.5 Concentration Limits
plt.ylim(0,75)
#Date Limits
plt.xlim(pd.Timestamp('2015-01-01'), pd.Timestamp('2020-11-01'))

#Print
plt.savefig('../Images/AQI-AllYears.jpg')
plt.show()

# %%
# #Combined_AQI_csv["Date"]= dt.datetime(Combined_AQI_csv["Date"],"%b/%d/%Y")
# Combined_AQI_csv['Date'] = pd.to_datetime(Combined_AQI_csv.Date)
# Combined_AQI_csv['Date'] = Combined_AQI_csv['Date'].dt.strftime('%m/%d/%Y')

# #Week_DF = Combined_AQI_csv
# #Week_DF['Week'] = pd.to_datetime(Week_DF['Date']) - pd.to_timedelta(7, unit='d')
# #Week_DF = Week_DF.groupby(['Date', pd.Grouper(key='Date', freq='W-MON')])['Daily Mean PM2.5 Concentration'].sum().reset_index().sort_values('Date')
    
# Combined_AQI_csv["week"]=Combined_AQI_csv["Date"].dt.strftime("%V")    

#Combined_AQI_csv["week"]=Combined_AQI_csv["Date"].dt.week

#Week_DF = Combined_AQI_csv.groupby(pd.Grouper(key="Date",freq="1W")).mean()["Daily Mean PM2.5 Concentration"]
#Week_DF

# %%
# Calculate the correlation coefficient and linear regression model 
# Based on PM2.5 over Time

PM25 = Combined_AQI_csv["Daily Mean PM2.5 Concentration"]
dates = Combined_AQI_csv['Date']

plt.figure(figsize=(15,3))
# Regression
m_slope, m_int, m_r, m_p, m_std_err = st.linregress(Combined_AQI_csv.index, PM25)
regress_values = Combined_AQI_csv.index * m_slope + m_int
plt.plot(Combined_AQI_csv.index,regress_values,"r-")

# scatterplot (comment out everything except first dates line for regress to work, but then the dates won't work)
ax = plt.gca()
dates = [datetime.strptime(d, "%m/%d/%Y") for d in dates]
ax.set_xlim([dates[0], dates[-1]])
ax.xaxis.set_major_locator(mdates.YearLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y'))
ax.xaxis.set_minor_locator(mdates.MonthLocator(bymonth=(3,6,9), bymonthday=-1))
ax.xaxis.set_minor_formatter(mdates.DateFormatter('%b'))

plt.scatter(dates, PM25, marker="^", facecolors="xkcd:gray", edgecolors="black")
plt.title("PM2.5 Regression Analysis")
plt.xlabel("Time")
plt.xticks(rotation=45)
plt.ylabel("PM2.5 Concentration (ug/m3 LC)")
plt.show()


#Correlation Coefficient
#W=Combined_AQI_csv["Date"]
#A=Combined_AQI_csv["Daily Mean PM2.5 Concentration"]

# %%
#combined covid aqi path
combined_covid_path = "../Resources/combined_aqi_covid_dates.csv"
covid_df = pd.read_csv(combined_covid_path)

covid_df.head()
# Out:
#      Date  Month  Day  Year Source_x  Site ID_x  POC_x  \
# 0  1/1/15      1    1  2015      AQS  270530962      3
# 1  1/2/15      1    2  2015      AQS  270530962      3
# 2  1/3/15      1    3  2015      AQS  270530962      3
# 3  1/4/15      1    4  2015      AQS  270530962      3
# 4  1/5/15      1    5  2015      AQS  270530962      3
#
#    Daily Mean PM2.5 Concentration   UNITS_x  DAILY_AQI_VALUE_x  ...  \
# 0                             7.7  ug/m3 LC                 32  ...
# 1                             7.5  ug/m3 LC                 31  ...
# 2                            14.1  ug/m3 LC                 55  ...
# 3                             9.4  ug/m3 LC                 39  ...
# 4                            10.5  ug/m3 LC                 44  ...
#
#   totalTestResults  totalTestResultsIncrease  totalTestsAntibody  \
# 0              NaN                       NaN                 NaN
# 1              NaN                       NaN                 NaN
# ...

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')
#x_ticks = ["Mar 20"]
# make a plot
ax.plot(covid_df.Date, covid_df.DAILY_AQI_VALUE_x)
#append above if needed: , index=months, color="red", marker="o")
#dates = aqi_covid_5yrdf['Date']


#ax.set_xticks(mdates.MonthLocator(bymonth=(3,6,9), bymonthday=-1))



# set x-axis label
ax.set_xlabel("2015-2020",fontsize=14)
# set y-axis label
ax.set_ylabel("AQI pm2.5",color="red",fontsize=14)
# Out:
# Text(0, 0.5, 'AQI pm2.5')

# %%
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(covid_df.Date, covid_df.positive,color="blue",marker="o")
ax2.set_ylabel("MN Covid Cases",color="blue",fontsize=14)
plt.show()

ax2.xaxis.set_major_locator(years)
ax2.xaxis.set_major_formatter(years_fmt)
ax2.xaxis.set_minor_locator(months)

# save the plot as a file
fig.savefig('../Images/aqi_5yr.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')
#x_ticks = ["Mar 20"]
# make a plot
ax.plot(covid_df.Date, covid_df.DAILY_AQI_VALUE_y)
#append above if needed: , index=months, color="red", marker="o")
#dates = aqi_covid_5yrdf['Date']


#ax.set_xticks(mdates.MonthLocator(bymonth=(3,6,9), bymonthday=-1))



# set x-axis label
ax.set_xlabel("2015-2020",fontsize=14)
# set y-axis label
ax.set_ylabel("AQI pm2.5",color="red",fontsize=14)
# Out:
# Text(0, 0.5, 'AQI pm2.5')

# %%
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(covid_df.Date, covid_df.positive,color="blue",marker="o")
ax2.set_ylabel("MN Covid Cases",color="blue",fontsize=14)
plt.show()

ax2.xaxis.set_major_locator(years)
ax2.xaxis.set_major_formatter(years_fmt)
ax2.xaxis.set_minor_locator(months)

# save the plot as a file
fig.savefig('../Images/ozone_vs_covid.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
#combined covid aqi path
combined_covid_path2020 = "../Resources/combined_aqi_covid_dates2020.csv"
covid_df2020 = pd.read_csv(combined_covid_path2020)

#covid_df2020.head()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')
#x_ticks = ["Mar 20"]
# make a plot
ax.plot(covid_df2020.Date, covid_df2020.DAILY_AQI_VALUE_x)
#append above if needed: , index=months, color="red", marker="o")
#dates = aqi_covid_5yrdf['Date']


#ax.set_xticks(mdates.MonthLocator(bymonth=(3,6,9), bymonthday=-1))



# set x-axis label
ax.set_xlabel("Nov 2019 to Nov 2020",fontsize=14)
# set y-axis label
ax.set_ylabel("AQI pm2.5",color="red",fontsize=14)
# Out:
# Text(0, 0.5, 'AQI pm2.5')

# %%
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(covid_df2020.Date, covid_df2020.positive,color="blue",marker="o")
ax2.set_ylabel("MN Covid Cases",color="blue",fontsize=14)
plt.show()

ax2.xaxis.set_major_locator(years)
ax2.xaxis.set_major_formatter(years_fmt)
ax2.xaxis.set_minor_locator(months)

# save the plot as a file
fig.savefig('../Images/particulates_vs_covid2020.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()

years = mdates.YearLocator()   # every year
months = mdates.MonthLocator()  # every month
years_fmt = mdates.DateFormatter('%Y')
#x_ticks = ["Mar 20"]
# make a plot
ax.plot(covid_df2020.Date, covid_df2020.DAILY_AQI_VALUE_y)
#append above if needed: , index=months, color="red", marker="o")
#dates = aqi_covid_5yrdf['Date']


#ax.set_xticks(mdates.MonthLocator(bymonth=(3,6,9), bymonthday=-1))



# set x-axis label
ax.set_xlabel("Nov 2019 to Nov 2020",fontsize=14)
# set y-axis label
ax.set_ylabel("Ozone AQI",color="red",fontsize=14)
# Out:
# Text(0, 0.5, 'Ozone AQI')

# %%
# twin object for two different y-axis on the sample plot
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(covid_df2020.Date, covid_df2020.positive,color="blue",marker="o")
ax2.set_ylabel("MN Covid Cases",color="blue",fontsize=14)
plt.show()

ax2.xaxis.set_major_locator(years)
ax2.xaxis.set_major_formatter(years_fmt)
ax2.xaxis.set_minor_locator(months)

# save the plot as a file
fig.savefig('../Images/AQI_oz_vs_covid2020.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
